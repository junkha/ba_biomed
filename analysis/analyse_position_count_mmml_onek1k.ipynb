# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ser = pd.read_json("/home/junkhann/daten/intersect_position_count.json", typ="series", dtype={str})
df = ser.to_frame("position_count")
df = df.reset_index(names="pos")
df[["chromosome", "position"]] = df["pos"].str.split("-", n=1, expand=True)
df.shape
# Out:
# (4124732, 4)

# %%
df["position_count"].sum()
# Out:
# 19090241

# %%
df.head()
# Out:
#            pos  position_count chromosome   position
# 0  3-116723728               7          3  116723728
# 1  3-116725097               7          3  116725097
# 2  3-116725415               7          3  116725415
# 3  3-116726085               3          3  116726085
# 4  3-116726713               3          3  116726713

# %%
df["chromosome"].nunique()
# Out:
# 22

# %%
threshold = 40

# %%
# plot with log scale
df["position_count"].plot(kind="hist", bins=88, xlabel="position count values", ylabel="frequency (log scale)")
plt.yscale('log')
#plt.axvline(x=threshold, color="r")

# %%
# plot without log scale
df["position_count"].plot(kind="hist", bins=88, xlabel="position count values", ylabel="frequency")
#plt.axvline(x=threshold, color="r")
# Out:
# <Axes: xlabel='position count values', ylabel='frequency'>

# %%
df["position_count"].median()
# Out:
# 3.0

# %%
df["position_count"].mean()
# Out:
# 4.6282379073355555

# %%
df["position_count"].min()
# Out:
# 1

# %%
df["position_count"].max()
# Out:
# 88

# %%
plt.boxplot(df["position_count"])
#plt.yscale("log")
#plt.axhline(y=threshold)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc387491e40>,
#   <matplotlib.lines.Line2D at 0x7fc3874920e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc387492380>,
#   <matplotlib.lines.Line2D at 0x7fc387492620>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc387491ba0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc3874928c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc387492b60>],
#  'means': []}
