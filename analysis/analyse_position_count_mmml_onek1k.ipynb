# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
ser = pd.read_json("/home/junkhann/daten/LOH_position_count_mmml_onek1k.json", typ="series", dtype={str})
df = ser.to_frame("position_count")
df = df.reset_index(names="pos")
df[["chromosome", "position"]] = df["pos"].str.split("-", n=1, expand=True)
df.shape
# Out:
# (223063, 4)

# %%
df["position_count"].sum()
# Out:
# 235331

# %%
df.head()
# Out:
#         pos  position_count chromosome position
# 0  1-842013               1          1   842013
# 1  1-846398               1          1   846398
# 2  1-848445               1          1   848445
# 3  1-850780               1          1   850780
# 4  1-851190               1          1   851190

# %%
df["chromosome"].nunique()
# Out:
# 22

# %%
threshold = 40

# %%
# plot with log scale
df["position_count"].plot(kind="hist", bins=121, xlabel="position count values", ylabel="frequency (log scale)")
plt.yscale('log')
#plt.axvline(x=threshold, color="r")

# %%
# plot without log scale
df["position_count"].plot(kind="hist", bins=120, xlabel="position count values", ylabel="frequency")
#plt.axvline(x=threshold, color="r")
# Out:
# <Axes: xlabel='position count values', ylabel='frequency'>

# %%
df["position_count"].median()
# Out:
# 1.0

# %%
df["position_count"].mean()
# Out:
# 1.0549979153871327

# %%
df["position_count"].min()
# Out:
# 1

# %%
df["position_count"].max()
# Out:
# 6

# %%
plt.boxplot(df["position_count"])
#plt.yscale("log")
#plt.axhline(y=threshold)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1e26b185b0>,
#   <matplotlib.lines.Line2D at 0x7f1e26b186a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f1e26b19900>,
#   <matplotlib.lines.Line2D at 0x7f1e26b1a170>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1e26b19570>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1e26b190f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1e26b19420>],
#  'means': []}
